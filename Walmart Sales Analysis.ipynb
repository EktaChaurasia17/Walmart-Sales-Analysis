# %% [markdown]
# # Walmart Sales Analysis

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import os

# %%
os.chdir(r"C:\Users\EKTA\OneDrive\Desktop\port folio projects\Python_Port_Folio_Projects")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\EKTA\\OneDrive\\Desktop\\port folio projects\\Python_Port_Folio_Projects'

# %%
df = pd.read_excel("Walmart.xlsm")

# %%
df
# Out:
#             Order ID Order Date  Ship Date    Customer Name        Country  \
# 0     CA-2013-138688 2013-06-13 2013-06-17  Darrin Van Huff  United States
# 1     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 2     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 3     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# 4     CA-2011-115812 2011-06-09 2011-06-14  Brosina Hoffman  United States
# ...              ...        ...        ...              ...            ...
# 3198  CA-2013-125794 2013-09-30 2013-10-04     Maris LaWare  United States
# 3199  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3200  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3201  CA-2014-121258 2014-02-27 2014-03-04      Dave Brooks  United States
# 3202  CA-2014-119914 2014-05-05 2014-05-10     Chris Cortes  United States
#
#              City       State     Category  \
# ...

# %%
df.describe()
# Out:
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493233     3.828910    33.849032
# std      524.876877     2.260947   174.109081
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.852000
# 50%       60.840000     3.000000    11.166400
# 75%      215.809000     5.000000    33.000400
# max    13999.960000    14.000000  6719.980800

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Customer Name    0
# Country          0
# City             0
# State            0
# Category         0
# Product Name     0
# Sales            0
# Quantity         0
# Profit           0
# dtype: int64

# %% [markdown]
# ## State wise sales

# %%
sns.barplot(data=df , x = 'Sales' , y = 'State', );
plt.title("State Wise Sales");

# %% [markdown]
# *This chart shows that , product is more sold in these states - Wyoming , Nevada , Montana compare to other states.*

# %% [markdown]
# ## Category Wise Sales

# %%
sns.barplot( data= df , x = 'Sales' , y ='Category');

# %% [markdown]
# ## State Wise Profit

# %%
sns.barplot( data = df , x = 'Profit' , y = 'State');

# %% [markdown]
# ## Category Wise Profit

# %%
sns.barplot( data = df , x = 'Profit' , y = 'Category');

# %% [markdown]
# ## City Wise Profit

# %%
profit_by_city = df.groupby(['City'], as_index = False)['Profit'].sum().head(10)

ax=sns.barplot( data =profit_by_city  , x = 'Profit' , y = 'City');
for bars in ax.containers:
    ax.bar_label(bars);

# %% [markdown]
# ## Category Wise Profit

# %%
profit_by_city = df.groupby(['Category'], as_index = False)['Profit'].sum().head(10)

ax=sns.barplot( data =profit_by_city  , x = 'Profit' , y = 'Category')
for bars in ax.containers:
    ax.bar_label(bars)
